# %% [markdown]
# ### Class 5. Data Visualization with Seaborn and Plotly

# %%
""" 
Objectives:
1. Understanding the categories of visual plots
2. Visualize different categories of plots using seaborn 
3. Visualize different categories of plots interactively using plotly

installation: pip install seaborn plotly
"""

import seaborn as sns

sns.set(
    style='darkgrid',
    palette='flare',
    font='Arial',
    font_scale=1,
)

# %%
"""
Understanding the categories of visual plots

Statistical plots:
1. Relational plot (relplot): establishes relations between variables
   x = 1, y = 2
   x = 2, y = 4
   x = 3, y = 6
   independent variable: the values of the variable does not depend on other variables i.e. x
   dependent variable: the value of the variable depends on other variables i.e. y is a dependent variable as it changes based on x. 
2. Distributional plot (displot): visualizes the distribution of variables
3. Categorical plot (catplot): provides statistical information about the categorical variables

matplotlib > seaborn > plotly
"""

sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
""" Data Visualization using Seaborn """
tips = sns.load_dataset('tips')
fmri = sns.load_dataset('fmri')
penguins = sns.load_dataset('penguins')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Relational plots

# %%
""" Scatter Plot 

Statistics:

Correlation between variables
   [-1, 1]
   -1: Strongly negatively correlated 
   0: Not correlated
   1: Strongly positively correlated
"""

plot = sns.relplot(
    data=tips,
    x='total_bill',
    y='tip',
    kind='scatter'
)

__ = plot.set(
    xlabel='Total Bill (USD)',
    ylabel='Tip (USD)',
    title='Relation between Total Bill and Tip (USD)'
)

# %%
tips['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
plot = sns.relplot(
    data=tips,
    x='total_bill',
    y='tip',
    kind='scatter',
    height=4,
    hue='day',
)

plot.set(
    xlabel='Total Bill (USD)', 
    ylabel='Tip (USD)', 
    title='Total Bill Vs Tip'
)

# %%
tips['time'].value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
plot = sns.relplot(
    data=tips,
    x='total_bill',
    y='tip',
    kind='scatter',
    hue='sex', # categorical attribute
    col='time', # categorical attribute
    # style='smoker'
)

plot.set(
    xlabel='Total Bill (USD)', 
    ylabel='Tip (USD)', 
    title='Total Bill Vs Tip'
)

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
""" Line plot 
- to visualize the changes of a variable with respect to another variable.
"""

plot = sns.relplot(
    data=fmri,
    x='timepoint',
    y='signal',
    kind='line',
    height=4,
    col='region',
    hue='event',
)

plot.set(
    xlabel='Time plot', 
    ylabel='Signal'
)

# %% [markdown]
# ### Distributional plot

# %%
"""
Event: Waiting for a bus

 Day 1, wait time = 1 min
 Day 2, wait time = 2 min
 Day 3, wait time = 6 min
 Day 4, wait time = 3 min
 Day 5, wait time = 15 min
 Day 6, wait time = 8 min
 
Average waiting time: (1+2+6+3+15+8)/6 = 5.833 min

"""

penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
""" Distributional plot: Flipper length 

- Univariate distribution: Distribution of one variable/feature/column
- Bivariate distribution: Distribution of two variables/features/columns
- Multivariate distribution: Distribution of three or more variables/features/columns
"""

sns.displot(
    data=penguins,
    x='flipper_length_mm',
    bins=20
)

# %%
sns.displot(
    data=penguins,
    x='species',
    discrete=True,
    shrink=0.8,
)

# %%
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    hue='species',
    col='species',
)

# %%
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    hue='species',
    element='step',
    multiple='stack'
)

# %%
sns.displot(
    data=penguins,
    x='flipper_length_mm',
    hue='species',
    element='step',
    multiple='stack',
    stat='probability',
    row='species',
)

# %%
sns.displot(
    data=penguins,
    x="flipper_length_mm",
    kind='kde',
    fill=True,
    hue='species',
    # multiple='stack'
)

# %%
sns.displot(
    data=penguins, 
    x="bill_length_mm", 
    y="bill_depth_mm",
    cbar=True
)

# %%
sns.pairplot(penguins)

# %% [markdown]
# ### Categorical plot

# %%
""" Strip plot 
- It shows individual data points as a scatter plot along categorical axis.
- It visualizes outliers, clusters, and distribution.
- Limitations: data can overlap, making it hard to understand the distribution.
"""

sns.catplot(
    data=tips,
    x='day',
    y='total_bill',
    kind='strip',
)

# %%
sns.catplot(
    data=tips,
    x='day',
    y='total_bill',
    jitter=False,
    order=['Sun', 'Sat', 'Thur', 'Fri']
)

# %%
""" Swarm plot 
- It is similar to strip plot but adjust the points to avoid overlap.
- It can visualize outliers, clusters, and distribution for small dataset
- Limitation: Does not fit well for larger datasets for spacing issues.
"""

sns.catplot(
    data=tips,
    x='day',
    y='total_bill',
    kind='swarm',
    hue='smoker',
    col='smoker'
)

# %%
""" Box Plot 

Statistics:
 minimum, Q1 (25%), median, Q3(75%), maximum
 
- It shows distribution through statistics
- It visualizes outliers, distributions.
- Limitations: No information present for understanding data density.
"""

sns.catplot(
    data=tips,
    x="day",
    y="total_bill",
    kind="box",
)

# %%
""" Violine plot 

- It combines box plot and distribution density graph (KDE: Kernel Density Estimation)
- It visualizes data distribution and statistics
"""

sns.catplot(
    data=tips,
    x="day",
    y="total_bill",
    kind="violin",
    hue='smoker'
)

# %%
"""Count plot

Insight: Displays frequency counts of categories.
Use case: Useful for categorical distributions.
Limitation: Doesn't show numerical variable distributions.
"""
sns.catplot(
    data=tips, 
    x="day",
    kind="count"
)

# %%
""" Data visualization with plotly """

""" scatter plot with plotly 

sns            |   px
===============================
kind='scatter' | px.scatter
data           | data_frame
hue            | color
col            | facet_col
row            | facet_row

"""
import plotly.express as px

plot = px.scatter(
    data_frame=tips,
    x='total_bill',
    y='tip',
    color='sex',
    facet_col='time',
    symbol='smoker'
)

plot.update_layout(
    xaxis_title='Total Bill (USD)',
    yaxis_title='Tip (USD)',
    title='Total Bill Vs Tip',
)

plot.show()
# Out:
# <div>                            <div id="71baf354-8b59-44c6-91ce-e0a20c416d35" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("71baf354-8b59-44c6-91ce-e0a20c416d35")) {                    Plotly.newPlot(                        "71baf354-8b59-44c6-91ce-e0a20c416d35",                        [{"hovertemplate":"sex=Female\u003cbr\u003esmoker=No\u003cbr\u003etime=Dinner\u003cbr\u003etotal_bill=%{x}\u003cbr\u003etip=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Female, No","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Female, No","orientation":"v","showlegend":true,"x":[16.99,24.59,35.26,14.83,10.33,16.97,20.29,15.77,19.65,15.06,20.69,16.93,10.29,34.81,26.41,16.45,17.07,14.73,22.75,20.92,7.25,25.71,17.31,29.85,25.0,13.39,16.21,35.83,18.78],"xaxis":"x","y":[1.01,3.61,5.0,3.02,1.67,3.5,2.75,2.23,3.0,3.0,2.45,3.07,2.6,5.2,1.5,2.47,3.0,2.2,3.25,4.08,1.0,4.0,3.5,5.14,3.75,2.61,2.0,4.67,3.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"sex=Female\u003cbr\u003esmoker=No\u003cbr\u003etime=Lunch\u003cbr\u003etotal_bill=%{x}\u003cbr\u003etip=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"